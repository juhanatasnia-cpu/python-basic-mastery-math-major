# %% [markdown]
# 2.1. Assign a message to a variable, and then print that message.
#
# 2.2 Then change the value of the message and then print the new message.

# %%
message='Machine learning is based on heavy Mathematics'
print(message)

message='you need to have solid understanding on calculus before starting Ml'
print(message)
# Out:
# Machine learning is based on heavy Mathematics
# you need to have solid understanding on calculus before starting Ml

# %% [markdown]
# 2.3. Personal Message: Use a variable to represent a person's name and then print that person. Your message should be simple. Such as, "Hello Eric, would you like to learn some Python today?"

# %%
Matthus="Hi,Matthus.If you don't mind, Can you land me your Math notes?"
print(Matthus)
# Out:
# Hi,Matthus.If you don't mind, Can you land me your Math notes?

# %% [markdown]
# 2.4. Print the person's name in lowercase, uppercase and title case.

# %%
name='Matthus'
print(name)
print(name.lower())
print(name.upper())
print(name.title())
# Out:
# Matthus
# matthus
# MATTHUS
# Matthus

# %% [markdown]
# 2.5. Find a quote from a famous person you admire.Print the quote and the name of it's author.

# %%
famous_person='Albert Einstein'
print(f"{famous_person} once said,'A person who never made a mistake never tried anything new.'")
# Out:
# Albert Einstein once said,'A person who never made a mistake never tried anything new.'
