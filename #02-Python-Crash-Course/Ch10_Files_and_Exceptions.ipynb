# %% [markdown]
# 1. Reading from a file:
#
# i. Reading the contents of a file:

# %%
3.141592653589793238462643383279

# %%
from pathlib import Path #pathlib=Module, Path is the file. A path is the exact location of a file or folder on a system.
path=Path('pi_digits.txt')
contents=path.read_text()
print(contents)
#Library: A module that provides specific functionality like this is called a library.It makes easier to work with files and dictionaries.
